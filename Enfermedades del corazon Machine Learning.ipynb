# %% [markdown]
# <div style="background: #27AE60; color: #fff; padding: 1em 2em 1.5em 2em; border-radius: 3px; font-weight: bold; margin-bottom: 20px;">
#     <h4 style="color: #fff; font-size: 24px; font-weight: bold;">Proyecto de Machine Learning 2023</h4>
# </div>
#
# <table class="tabla-transparente" style="border-collapse: collapse; width: 100%;">
#   <tr>
#     <td style="padding: 20px; background-color: white; color: #333; border-right: 1px solid transparent;">
#       <img src="https://gravitar.biz/wp-content/uploads/2021/02/Data-Science.png" alt="Imagen: datanautas" style="width: 300px; height: auto;">
#     </td>
#     <td style="padding: 20px; background-color: white; color: #333;">
#       <h5 style="font-weight: bold;"> Enunciamos los pasos principales a seguir:</h5>
#       <ul>
#         <li>Analizar el panorama general y entender el problema</li>
#         <li>Obtener los datos</li>
#         <li>Preparar los datos para los algoritmos de Machine Learning</li>
#         <li>Seleccionar los modelos y realizar el entrenamiento (train)</li>
#         <li>Ajustar (fine tune) el modelo</li>
#         <li>Presentar su solución</li>
#         <li>Iniciar (Launch), monitorear y mantener el sistema</li>
#       </ul>
#     </td>
#   </tr>
# </table>

# %% [markdown]
# <div style="background:#0c1778;color:#fff;padding:1em 2em 1.5em 2em;border-radius: 3px;font-weight:bold">
#     <strong>
#         <h4 style = "color:#fff"><font size = 5>1.Analizar el caso en general y entendimiento del problema</font></h4>
#     </strong>
# </div><br>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="es">
# <head>
#   <meta charset="UTF-8">
#   <style>
#     .titulo {
#       color: #c0392b; /* Color rojo intenso */
#       font-weight: bold;
#       font-size: 28px; /* Tamaño del texto */
#       border-bottom: 4px solid #2980b9; /* Borde inferior azul */
#       padding-bottom: 8px; /* Espacio debajo del texto */
#       width: fit-content; /* Ancho ajustado al contenido */
#
#     }
#   </style>
# </head>
# <body>
#   <div class="titulo">Enfermedades Cardíacas: El Impacto Silencioso</div>
# </body>
# </html>

# %% [markdown]
# <table class="tabla-transparente" style="border-collapse: collapse; width: 100%; border: 2px solid #3498db;">
#   <tr>
#     <td style="padding: 10px; background-color: #3498db; color: #333; text-align: center; border-right: 1px solid transparent; padding-bottom: 0;">
#       <img src="https://alodoctor.co/assets/iblog/post/50.jpg" alt="Imagen: enfermedades cardiovasculares" style="width: 85%; max-width: 800px; height: auto;">
#     </td>
#     <td style="padding: 10px; background-color: #3498db; color: #333; vertical-align: top; width: 30%; padding-bottom: 0;">
#       <p style="font-size: 13px; margin-bottom: 10px;">Las <strong>Enfermedades Cardiovasculares</strong> se han convertido en una amenaza significativa para los sistemas de salud a nivel mundial. Este diagnóstico en particular ha ocasionado una cantidad considerable de pérdidas de vidas en varios países. Según datos de la Organización Mundial de la Salud (OMS), estas enfermedades representan una causa relevante de mortalidad, siendo responsables de aproximadamente 9.4 millones de fallecimientos al año, lo que equivale al 16.5% del total de muertes anuales. Se estima que la hipertensión sola contribuye al 51% de las muertes por accidentes cerebrovasculares (ACV) y al 45% de las muertes por enfermedad coronaria.</p>
#       <p style="font-size: 13px; margin-bottom: 0;">Esta problemática ha generado un gran interés en la investigación, con un enfoque creciente en el análisis de estas enfermedades. La implementación de sistemas informáticos avanzados se perfila como una herramienta prometedora para identificar tempranamente a los pacientes en riesgo de padecer dichas enfermedades.</p>
#     </td>
#   </tr>
# </table>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="es">
# <head>
#   <meta charset="UTF-8">
#   <style>
#     .titulo {
#       color: #c0392b; /* Color rojo intenso */
#       font-weight: bold;
#       font-size: 28px; /* Tamaño del texto */
#       border-bottom: 4px solid #2980b9; /* Borde inferior azul */
#       padding-bottom: 8px; /* Espacio debajo del texto */
#       width: fit-content; /* Ancho ajustado al contenido */
#
#     }
#   </style>
# </head>
# <body>
#   <div class="titulo">Problema: </div>
# </body>
# </html>

# %% [markdown]
# <table class="tabla-transparente" style="border-collapse: collapse; width: 100%; border: 2px solid #3498db;">
#   <tr>
#     <td style="padding: 14px; background-color: #3498db; color: #333; vertical-align: top; width: 30%; padding-bottom: 0;">
#       <p style="font-size: 16px; margin-bottom: 10px;">Mediante el análisis de datos, se identificarán factores de riesgo asociados con enfermedades cardiovasculares, tales como la edad, la presión arterial, el hábito de fumar, niveles elevados de colesterol, presencia de diabetes y otras variables relevantes. Este análisis tiene como objetivo principal asistir al profesional de la salud en la detección temprana del riesgo de enfermedad cardiovascular en sus pacientes.</p>
#     </td>
#   </tr>
# </table>

# %% [markdown]
# <div style="background:#0c1778;color:#fff;padding:1em 2em 1.5em 2em;border-radius: 3px;font-weight:bold">
#     <strong>
#         <h4 style = "color:#fff"><font size = 5>2. Obtención de los datos</font></h4>
#     </strong>
# </div><br>

# %% [markdown]
# <table class="tabla-transparente" style="border-collapse: collapse; width: 100%; border: 2px solid #3498db;">
#   <tr>
#     <td style="padding: 14px; background-color: #3498db; color: #333; vertical-align: top; width: 30%; padding-bottom: 0;">
#       <p style="font-size: 16px; margin-bottom: 10px;"> Se conforma de bases de datos: Cleveland, Hungría, Suiza y VA Long Beach. Características del conjunto de datos: multivariado. Instancias: 303. Características: 13
#       Esta base de datos contiene 76 atributos, pero todos los experimentos publicados hacen referencia al uso de un subconjunto de 14 de ellos. En particular, la base de datos de Cleveland es la única que han utilizado los investigadores de ML hasta la fecha. El campo "objetivo" se refiere a la presencia de enfermedad cardíaca en el paciente. Tiene un valor entero de 0 (sin presencia) a 4. Los experimentos con la base de datos de Cleveland se han concentrado en simplemente intentar distinguir la presencia (valores 1,2,3,4) de la ausencia (valor 0).
#       <strong>Los datos son obtenidos de <strong>: https://archive.ics.uci.edu/dataset/45/heart+disease</p>
#     </td>
#   </tr>
# </table>

# %% [markdown]
# <div style="background:#0c1778;color:#fff;padding:1em 2em 1.5em 2em;border-radius: 3px;font-weight:bold">
#     <strong>
#         <h4 style = "color:#fff"><font size = 5>Importaciones</font></h4>
#     </strong>
# </div><br>

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import  LinearRegression, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import mean_squared_error
import seaborn as sns
import matplotlib.pyplot as plt
from pyod.models.knn import KNN
import plotly.express as px
from scipy.stats import shapiro
import matplotlib.ticker as mtick

import geopandas as gpd

import folium 
import json
import requests
import pandas as pd
import matplotlib.pyplot as plt
import branca 
import seaborn as sns
import numpy as np
from folium.plugins import StripePattern
import geopandas as gpd
# %matplotlib inline

# %% [markdown]
# <div style="background:#0c1778;color:#fff;padding:1em 2em 1.5em 2em;border-radius: 3px;font-weight:bold">
#     <strong>
#         <h4 style = "color:#fff"><font size = 5>Carga de los datos</font></h4>
#     </strong>
# </div><br>

# %%
df = pd.read_csv('CD_16_ML-DecisionTree-RandomForest_EnfermedadesCorazon/datos/heart_disease.csv')

# %% [markdown]
# <div style="background:#0c1778;color:#fff;padding:1em 2em 1.5em 2em;border-radius: 3px;font-weight:bold">
#     <strong>
#         <h4 style = "color:#fff"><font size = 5>2. Descubrimiento y visualización los datos para obtener información</font></h4>
#     </strong>
# </div><br>

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Mostrar las columnas
df.columns.values
# Out:
# array(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg',
#        'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype=object)

# %%
# Mostrar el número de filas y columnas
df.shape
# Out:
# (303, 14)

# %%
# Mostrar el tipo de variables
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
| Columna    | Tipo       | Descripción                                         | Unidad      | Valores Faltantes |
|------------|------------|-----------------------------------------------------|-------------|-------------------|
| age        | Integer    | Edad                                                | años        | no                |
| sex        | Categórico | Sexo                                                | -           | no                |
| cp         | Categórico | Tipo de dolor de pecho                              | -           | no                |
| trestbps   | Integer    | Presión arterial en reposo al ingresar al hospital  | mm Hg       | no                |
| chol       | Integer    | Colesterol sérico                                   | mg/dl       | no                |
| fbs        | Categórico | Azúcar en sangre en ayunas > 120 mg/dl              | -           | no                |
| restecg    | Categórico | Electrocardiograma en reposo                        | -           | no                |
| thalach    | Integer    | Ritmo cardíaco máximo alcanzado                     | -           | no                |
| exang      | Categórico | Angina inducida por ejercicio                       | -           | no                |
| oldpeak    | Integer    | Depresión del segmento ST inducida por ejercicio    | -           | no                |
| slope	     | Categórico |				                                        |             | no                |
| ca	     | Integer    |	number of major vessels (0-3) colored by flourosopy	|             | yes               |
| thal	     | Categórico |				                                        |             | yes               |

# %%
# Histograma de todas las variables numericas
df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'age'}>, <Axes: title={'center': 'sex'}>,
#         <Axes: title={'center': 'cp'}>,
#         <Axes: title={'center': 'trestbps'}>],
#        [<Axes: title={'center': 'chol'}>,
#         <Axes: title={'center': 'fbs'}>,
#         <Axes: title={'center': 'restecg'}>,
#         <Axes: title={'center': 'thalach'}>],
#        [<Axes: title={'center': 'exang'}>,
#         <Axes: title={'center': 'oldpeak'}>,
#         <Axes: title={'center': 'slope'}>,
#         <Axes: title={'center': 'ca'}>],
#        [<Axes: title={'center': 'thal'}>,
#         <Axes: title={'center': 'target'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
# Hacer un histograma de la edad

plt.figure(figsize=(7, 2))
plt.hist(df['age'], bins=50)
plt.title('Distribución de Edades', fontsize=10)
plt.xlabel('Edad', fontsize=7)
plt.ylabel('Frecuencia', fontsize=7)
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.show()

# %%
#Diagramas de correlación
from pandas.plotting import scatter_matrix
atributos=['age','chol','thalach', 'trestbps']
scatter_matrix(df[atributos],figsize=(12,8))
# Out:
# array([[<Axes: xlabel='age', ylabel='age'>,
#         <Axes: xlabel='chol', ylabel='age'>,
#         <Axes: xlabel='thalach', ylabel='age'>,
#         <Axes: xlabel='trestbps', ylabel='age'>],
#        [<Axes: xlabel='age', ylabel='chol'>,
#         <Axes: xlabel='chol', ylabel='chol'>,
#         <Axes: xlabel='thalach', ylabel='chol'>,
#         <Axes: xlabel='trestbps', ylabel='chol'>],
#        [<Axes: xlabel='age', ylabel='thalach'>,
#         <Axes: xlabel='chol', ylabel='thalach'>,
#         <Axes: xlabel='thalach', ylabel='thalach'>,
#         <Axes: xlabel='trestbps', ylabel='thalach'>],
#        [<Axes: xlabel='age', ylabel='trestbps'>,
#         <Axes: xlabel='chol', ylabel='trestbps'>,
#         <Axes: xlabel='thalach', ylabel='trestbps'>,
#         <Axes: xlabel='trestbps', ylabel='trestbps'>]], dtype=object)
